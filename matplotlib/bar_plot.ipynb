# %%
import matplotlib.pyplot as plt

# %%
years = [1990,1992,1994,1996,1998,2000];
runs = [300,200,800,1000,1500,200];

# %%
plt.bar(years,runs);
plt.xlabel("years");
plt.ylabel("runs scored");
plt.title("sachin tendulkar yearly runs");
